# %%
import matplotlib.pyplot as plt
from mmrely import *
import numpy as np
import pickle
import os
import glob
import pandas as pd
from scipy.interpolate import interp1d, PchipInterpolator, Akima1DInterpolator

plt.rcParams['font.family'] = 'Times New Roman'

# %%
plt.figure(figsize=(5,5))

a = pickle.load(open('los_list_1.pkl', 'rb'))
# plt.plot(a[0]['LOS'])
los = a[0]['LOS']
x = np.linspace(0,2,2048)
plt.plot(x,los, color='black')

ax = plt.gca()
ax.set_xticks([0, 1, 2])

fontsize = 25

ax.set_xlabel('Time (s)', fontsize=fontsize)
ax.set_ylabel(r'Aspect Angle ($\circ$)', fontsize=fontsize)

plt.tick_params(axis='both', which='major', labelsize=25)
ax.get_yaxis().get_offset_text().set_size(25)  # Adjust the size as needed


plt.tick_params(direction='in')

plt.subplots_adjust(left=0.1, right=0.95, top=0.95, bottom=0.15)

plt.savefig("./LOS.png", dpi=500, bbox_inches='tight')

# %%
plt.figure(figsize=(5,5))

a = pickle.load(open('los_list_1.pkl', 'rb'))
# plt.plot(a[0]['LOS'])
los = a[0]['LOS']
x = np.linspace(0,2,2048)
plt.plot(x,los, color='black')

ax = plt.gca()
ax.set_xticks([0, 1, 2])

fontsize = 25

ax.set_xlabel('Time (s)', fontsize=fontsize)
ax.set_ylabel(r'Aspect Angle ($\circ$)', fontsize=fontsize)

plt.tick_params(axis='both', which='major', labelsize=25)
ax.get_yaxis().get_offset_text().set_size(25)  # Adjust the size as needed


plt.tick_params(direction='in')

plt.subplots_adjust(left=0.1, right=0.95, top=0.95, bottom=0.15)
plt.ylim(49, 49.2)

plt.savefig("./move_los.png", dpi=500, bbox_inches='tight')

# %%
plt.figure(figsize=(5,5))

a = pickle.load(open('los_list_1.pkl', 'rb'))
# plt.plot(a[0]['LOS'])
R = [np.linalg.norm(i) for i in a[0]['Radar_warhead']]
plt.plot(x, R)

ax = plt.gca()
ax.set_xticks([0, 1, 2])

fontsize = 25

ax.set_xlabel('Time (s)', fontsize=fontsize)
ax.set_ylabel(r'Range (m)', fontsize=fontsize)

plt.tick_params(axis='both', which='major', labelsize=25)
ax.get_yaxis().get_offset_text().set_size(25)  # Adjust the size as needed


plt.tick_params(direction='in')

plt.subplots_adjust(left=0.1, right=0.95, top=0.95, bottom=0.15)

plt.savefig("./Range.png", dpi=500, bbox_inches='tight')

# %%
plt.figure(figsize=(5,5))

a = pickle.load(open('los_list_1.pkl', 'rb'))
dt = 1/1024
# plt.plot(a[0]['LOS'])
R = [np.linalg.norm(i) for i in a[0]['Radar_warhead']]
# 计算径向速度 v_r
v_r = np.diff(R) / dt
v_r = np.append(v_r, v_r[-1])  # 补齐数组长度
plt.plot(x, v_r)

ax = plt.gca()
ax.set_xticks([0, 1, 2])

fontsize = 25

ax.set_xlabel('Time (s)', fontsize=fontsize)
ax.set_ylabel(r'velocity (m/s)', fontsize=fontsize)

plt.tick_params(axis='both', which='major', labelsize=25)
ax.get_yaxis().get_offset_text().set_size(25)  # Adjust the size as needed


plt.tick_params(direction='in')

plt.subplots_adjust(left=0.1, right=0.95, top=0.95, bottom=0.15)

plt.savefig("./velocity.png", dpi=500, bbox_inches='tight')

# %%
a[0]['Orbit_ID'], a[0]['Radar_ID']
# Out:
# (0, 0)
